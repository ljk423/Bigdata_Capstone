# %%
import pandas as pd

# %%
def go(yr, D):
    df1 = pd.read_excel('/Users/leejunki/weather/'+str(yr)+'/'+'_1.xlsx', encoding='euc-kr')
    df2 = pd.read_excel('/Users/leejunki/weather/'+str(yr)+'/'+'_2.xlsx', encoding='euc-kr')
    df3 = pd.read_excel('/Users/leejunki/weather/'+str(yr)+'/'+'_3.xlsx', encoding='euc-kr')
    df4 = pd.read_excel('/Users/leejunki/weather/'+str(yr)+'/'+'_4.xlsx', encoding='euc-kr')
    
    res1 = df1.groupby([df1['지역'], df1['측정소코드'], df1['측정소명'], df1['측정일시']//100],
                       as_index=False).mean()
    res2 = df2.groupby([df2['지역'], df2['측정소코드'], df2['측정소명'], df2['측정일시']//100],
                       as_index=False).mean()
    res3 = df3.groupby([df3['지역'], df3['측정소코드'], df3['측정소명'], df3['측정일시']//100],
                       as_index=False).mean()
    res4 = df4.groupby([df4['지역'], df4['측정소코드'], df4['측정소명'], df4['측정일시']//100],
                       as_index=False).mean()
    
    res1['일시'] = res1['측정일시'] // 100
    res2['일시'] = res2['측정일시'] // 100
    res3['일시'] = res3['측정일시'] // 100
    res4['일시'] = res4['측정일시'] // 100
    
    cols = res1.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res1 = res1[cols]

    cols = res2.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res2 = res2[cols]

    cols = res3.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res3 = res3[cols]

    cols = res4.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res4 = res4[cols]
    
    res1['일시'] = res1['일시'].astype('int')
    del res1['측정일시']

    res2['일시'] = res2['일시'].astype('int')
    del res2['측정일시']

    res3['일시'] = res3['일시'].astype('int')
    del res3['측정일시']

    res4['일시'] = res4['일시'].astype('int')
    del res4['측정일시']
    
    res = pd.concat([res1, res2, res3, res4])
    res.groupby([res['지역'], res['일시']], as_index=False).mean()
    data = res.groupby([res['지역'], res['일시']], as_index=False).mean()
    data['지역명'] = data.apply(lambda row: row['지역'][:2], axis=1)
    temp = data.groupby([data['지역명'], data['일시']], as_index=False).mean()
    
    del temp['측정소코드']
    temp = temp.replace({"지역명": D})
    temp.to_csv('/Users/leejunki/weather/finedust'+str(yr)+'.csv', encoding='euc-kr')

# %%
def go_csv(yr, D):
    df1 = pd.read_csv('/Users/leejunki/weather/'+str(yr)+'/'+'_1.csv', encoding='euc-kr')
    df2 = pd.read_csv('/Users/leejunki/weather/'+str(yr)+'/'+'_2.csv', encoding='euc-kr')
    df3 = pd.read_csv('/Users/leejunki/weather/'+str(yr)+'/'+'_3.csv', encoding='euc-kr')
    df4 = pd.read_csv('/Users/leejunki/weather/'+str(yr)+'/'+'_4.csv', encoding='euc-kr')

    res1 = df1.groupby([df1['지역'], df1['측정소코드'], df1['측정소명'], df1['측정일시']//100],
                       as_index=False).mean()
    res2 = df2.groupby([df2['지역'], df2['측정소코드'], df2['측정소명'], df2['측정일시']//100],
                       as_index=False).mean()
    res3 = df3.groupby([df3['지역'], df3['측정소코드'], df3['측정소명'], df3['측정일시']//100],
                       as_index=False).mean()
    res4 = df4.groupby([df4['지역'], df4['측정소코드'], df4['측정소명'], df4['측정일시']//100],
                       as_index=False).mean()

    res1['일시'] = res1['측정일시'] // 100
    res2['일시'] = res2['측정일시'] // 100
    res3['일시'] = res3['측정일시'] // 100
    res4['일시'] = res4['측정일시'] // 100

    cols = res1.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res1 = res1[cols]

    cols = res2.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res2 = res2[cols]

    cols = res3.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res3 = res3[cols]

    cols = res4.columns.tolist()
    cols = cols[:3] + [cols[-1]] + cols[3:-1]
    res4 = res4[cols]

    res1['일시'] = res1['일시'].astype('int')
    del res1['측정일시']

    res2['일시'] = res2['일시'].astype('int')
    del res2['측정일시']

    res3['일시'] = res3['일시'].astype('int')
    del res3['측정일시']

    res4['일시'] = res4['일시'].astype('int')
    del res4['측정일시']

    res = pd.concat([res1, res2, res3, res4])
    res.groupby([res['지역'], res['일시']], as_index=False).mean()
    data = res.groupby([res['지역'], res['일시']], as_index=False).mean()
    data['지역명'] = data.apply(lambda row: row['지역'][:2], axis=1)
    temp = data.groupby([data['지역명'], data['일시']], as_index=False).mean()

    del temp['측정소코드']
    temp = temp.replace({"지역명": D})
    temp.to_csv('/Users/leejunki/weather/finedust'+str(yr)+'.csv', encoding='euc-kr')

# %%
yr = 2002

# %%
A = [11, 26, 27, 28, 29, 30, 31, 36, 41, 42, 43, 44, 45, 46, 47, 48, 49]
B = ['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남',
    '전북','전남','경북','경남','제주']
D = dict(zip(B, A))

# %%
f = {'2002':'xlsx','2003':'xlsx','2004':'xlsx','2005':'xlsx','2006':'xlsx','2007':'xlsx',
     '2008':'xlsx','2009':'xlsx','2010':'xlsx','2011':'xlsx','2012':'xlsx','2013':'xlsx',
     '2014':'csv','2015':'csv','2016':'csv','2017':'xlsx','2018':'xlsx'}

# %%
f = {'2016':'csv','2017':'xlsx','2018':'xlsx'}

# %%
for yr, form in f.items():
    if form == "xlsx":
        go(yr, D)
    else:
        go_csv(yr, D)

# %%
res = pd.concat([res1, res2, res3, res4])
data = res.groupby([res['지역'], res['일시']], as_index=False).mean()

# %%
data = res.groupby([res['지역'], res['일시']], as_index=False).mean()

# %%
data.head()
# Out:
#        지역        일시     측정소코드       SO2        CO        O3       NO2  \
# 0  강원 강릉시  20020101  632132.0  0.001042  0.829167  0.032667  0.011083
# 1  강원 강릉시  20020102  632132.0  0.001167  0.916667  0.035958  0.010917
# 2  강원 강릉시  20020103  632132.0  0.001208  0.895833  0.036042  0.011042
# 3  강원 강릉시  20020104  632132.0  0.001083  1.000000  0.033292  0.010958
# 4  강원 강릉시  20020105  632132.0  0.001000  0.862500  0.030417  0.010792
#
#          PM10
# 0   36.625000
# 1   37.166667
# 2   38.875000
# 3   37.708333
# 4 -563.666667

# 6199   43  20161209  0.003526  0.700714  0.017258  0.019937  43.825735
# 6200   43  20161210  0.003331  0.665856  0.010216  0.024025  39.704006
# 6201   43  20161211  0.003178  0.779745  0.007623  0.026529  44.979972
# 6202   43  20161212  0.004157  0.974653  0.004678  0.030462  61.129630
# 6203   43  20161213  0.004475  0.970023  0.006895  0.030470  57.765046
# 6204   43  20161214  0.003651  0.699950  0.007601  0.026653  58.472222
# 6205   43  20161215  0.003266  0.448495  0.017197  0.019701  35.870536
# 6206   43  20161216  0.004133  0.633545  0.012591  0.023010  34.884762
# 6207   43  20161217  0.005251  0.835880  0.011228  0.027608  47.825231
# 6208   43  20161218  0.003769  0.990394  0.008988  0.023629  52.008102
# 6209   43  20161219  0.003535  0.919160  0.004958  0.024839  44.181382
# 6210   43  20161220  0.003584  1.069928  0.006513  0.024457  62.984954
# 6211   43  20161221  0.003243  0.933512  0.007385  0.024043  49.725694
# 6212   43  20161222  0.002565  0.614539  0.020299  0.013010  18.343247
# 6213   43  20161223  0.002459  0.469213  0.022289  0.011187  33.300926
# 6214   43  20161224  0.002958  0.695255  0.012509  0.019744  61.488426
# 6215   43  20161225  0.002901  1.071417  0.004163  0.024012  68.449239
# 6216   43  20161226  0.002928  1.030903  0.004118  0.025829  43.170139
# 6217   43  20161227  0.002783  0.578320  0.014949  0.020626  37.355446
# 6218   43  20161228  0.003252  0.646506  0.007748  0.026813  43.776991
# 6219   43  20161229  0.003539  0.590856  0.012675  0.023957  37.615388
# 6220   43  20161230  0.003543  0.693171  0.009639  0.024714  35.230425
# 6221   43  20161231  0.004466  0.994329  0.005969  0.025789  50.515902
#
#            PM25
# 0     43.823962
# 1     38.521739
# 2     53.994746
# 3     55.925000
# 4     16.179892
# 5     27.898755
# 6     31.265217
# 7     21.720833
# 8     23.354167
# 9     23.125000
# 10    20.838420
# 11    23.731439
# 12    24.170685
# 13    21.846812
# 14    35.575906
# 15    44.415909
# 16    53.566667
# 17    35.218643
# 18    14.398030
# 19    25.438676
# 20    34.379545
# 21    32.204819
# 22    19.400119
# 23    24.880710
# 24    26.244824
# 25    35.637500
# 26    49.358333
# 27    42.964855
# 28    30.042063
# 29    22.929351
# ...         ...
# 6192  22.031944
# 6193  40.241667
# 6194  57.299638
# 6195  65.958333
# 6196  18.286051
# 6197  35.567478
# 6198  55.631220
# 6199  34.076932
# 6200  28.087742
# 6201  31.972222
# 6202  40.137500
# 6203  43.332488
# 6204  44.018056
# 6205  23.197222
# 6206  19.980797
# 6207  30.012742
# 6208  37.806944
# 6209  32.165025
# 6210  45.780556
# 6211  35.778804
# 6212  12.870833
# 6213  25.168841
# 6214  51.697826
# 6215  56.071920
# 6216  35.922464
# 6217  27.647222
# 6218  27.484031
# 6219  21.397585
# 6220  23.419143
# 6221  40.820833
#
# [6222 rows x 8 columns]
